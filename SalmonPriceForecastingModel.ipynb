# %% [markdown]
# Price Forecasting Model for Atlantic, Norwegian Farmed Salmon

# %%
#Importing necessary libraries
import pandas as pd
import os

# %% [markdown]
# Data Cleaning Process

# %%
#Creating a DataFrame
Data = pd.DataFrame()




print(Data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
